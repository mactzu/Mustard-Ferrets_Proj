# %%
import yfinance as yf
# %matplotlib inline
import matplotlib.pyplot as plt

import numpy as np
import pandas as pd

# %%
five_stk_d = pd.read_csv("topfivestk_d.csv")
five_stk_d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 508 entries, 0 to 507
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           508 non-null    object
#  1   Nab Close      508 non-null    float64
#  2   CBA Close      508 non-null    float64
#  3   ANZ Close      508 non-null    float64
#  4   Westpac Close  508 non-null    float64
#  5   Maq Close      508 non-null    float64
# dtypes: float64(5), object(1)
# memory usage: 23.9+ KB

# %%
five_stk_q = pd.read_csv("topfivestk_q.csv")

quarter = ["May-18","Aug-18", "Nov-18", "Feb-19", "May-19", "Aug-19","Nov-19", "Feb-20", "May-20", "Aug-20"]
five_stk_q["qrter"] = quarter
#up = pd.read_csv("update.csv")
#up.set_index("1/1/18", inplace=True)
five_stk_q
# Out:
#          Date  Nab Close  CBA Close  ANZ Close  Westpac Close   Maq Close  \
# 0  2018-07-01  24.682455  63.940411  25.744183      25.290392  116.065094
# 1  2018-10-01  21.363058  66.853653  22.345728      22.673519  100.051353
# 2  2019-01-01  23.320543  65.237488  24.502548      24.293566  121.286674
# 3  2019-04-01  24.658680  78.592552  26.554623      26.580462  117.509933
# 4  2019-07-01  28.333557  76.741196  27.650820      28.786436  126.496262
# 5  2019-10-01  23.496817  78.129562  23.879370      23.532232  133.029526
# 6  2020-01-01  16.384953  60.450180  16.959999      16.500000   84.281120
# 7  2020-04-01  17.897711  69.419998  18.639999      17.950001  116.568405
# 8  2020-07-01  18.340000  71.419998  18.809999      18.160000  123.820000
# 9  2020-07-08  18.139999  71.180000  18.660000      17.950001  122.099998
#
#     qrter
# 0  May-18
# 1  Aug-18
# 2  Nov-18
# 3  Feb-19
# 4  May-19
# 5  Aug-19
# 6  Nov-19
# 7  Feb-20
# 8  May-20
# 9  Aug-20

# %%
fx_rates_d = pd.read_csv("2018_to_08-07-20.csv", delimiter=",")

# %%
uploy = pd.read_csv("uemploy_dat.csv")
uploy.set_index("Unnamed: 0", inplace=True)
uploy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 165 entries, May-79 to May-20
# Data columns (total 20 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   National Seasonally Adjusted  160 non-null    float64
#  1   Unnamed: 2                    0 non-null      float64
#  2   Unnamed: 3                    0 non-null      float64
#  3   Unnamed: 4                    0 non-null      float64
#  4   Unnamed: 5                    0 non-null      float64
#  5   Unnamed: 6                    0 non-null      float64
#  6   Unnamed: 7                    0 non-null      float64
#  7   Unnamed: 8                    0 non-null      float64
#  8   Unnamed: 9                    0 non-null      float64
#  9   Unnamed: 10                   0 non-null      float64
#  10  Unnamed: 11                   0 non-null      float64
#  11  Unnamed: 12                   0 non-null      float64
# ...

# %%
uploy_df = uploy["National Seasonally Adjusted"]
uploy_df
# Out:
# Unnamed: 0
# May-79     43.5
# Aug-79     41.9
# Nov-79     38.4
# Feb-80     40.6
# May-80     36.7
#           ...
# May-19    227.9
# Aug-19    224.2
# Nov-19    227.1
# Feb-20    227.3
# May-20    129.1
# Name: National Seasonally Adjusted, Length: 165, dtype: float64

# %%
#five_stk_qplus = pd.merge(five_stk_q, uploy, on="", how="outer" )

# %%
uploy_df = pd.read_csv('uemploy_dat.csv', usecols=[0,1])
uploy_df = uploy_df.iloc[-9 :]
uploy_df.rename(columns={"Unnamed: 0": "qrter"},inplace=True)
f= pd.merge(five_stk_q, uploy_df, on="qrter", how="outer" )
f.head(12)
# Out:
#          Date  Nab Close  CBA Close  ANZ Close  Westpac Close   Maq Close  \
# 0  2018-07-01  24.682455  63.940411  25.744183      25.290392  116.065094
# 1  2018-10-01  21.363058  66.853653  22.345728      22.673519  100.051353
# 2  2019-01-01  23.320543  65.237488  24.502548      24.293566  121.286674
# 3  2019-04-01  24.658680  78.592552  26.554623      26.580462  117.509933
# 4  2019-07-01  28.333557  76.741196  27.650820      28.786436  126.496262
# 5  2019-10-01  23.496817  78.129562  23.879370      23.532232  133.029526
# 6  2020-01-01  16.384953  60.450180  16.959999      16.500000   84.281120
# 7  2020-04-01  17.897711  69.419998  18.639999      17.950001  116.568405
# 8  2020-07-01  18.340000  71.419998  18.809999      18.160000  123.820000
# 9  2020-07-08  18.139999  71.180000  18.660000      17.950001  122.099998
#
#     qrter  National Seasonally Adjusted
# 0  May-18                         223.8
# 1  Aug-18                         228.6
# ...
